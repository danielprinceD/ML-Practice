# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
series = pd.Series(["Daniel","Bose","Aadhavan","Aravind"],index=[1,2,3,4])
series.name = "Students"
series.iloc[1]
# Out:
# 'Bose'

# %%
print(series)
print("\n")
print(dict(series))
# Out:
# 1      Daniel
# 2        Bose
# 3    Aadhavan
# 4     Aravind
# Name: Students, dtype: object
#
#
# {1: 'Daniel', 2: 'Bose', 3: 'Aadhavan', 4: 'Aravind'}

# %%
mark = pd.Series([98,99,95,99])
mark.name ="Score"

# %%
mark.plot.bar()
plt.xlabel("Person")
plt.tight_layout()
plt.show()

# %%
myDict_data = {
    'S.no' :[1,2,3],
    'Name ': ['One','Two','Three'],
    'Age':[10,15,13],
    'Marks':[90,70,20]
}
df = pd.DataFrame(myDict_data)
print(df)
# Out:
#    S.no  Name   Age  Marks
# 0     1    One   10     90
# 1     2    Two   15     70
# 2     3  Three   13     20

# %%
df.set_index('S.no',inplace=True)

# %%
df.shape
# Out:
# (3, 3)

# %%
df.Age.hist()
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Marks'}>]], dtype=object)

# %%
df['Marks'].hist(color='r')
# Out:
# <Axes: >
