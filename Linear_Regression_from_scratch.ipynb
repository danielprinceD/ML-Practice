# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(5,10,100)
y=x**2+2*x+5+np.random.randint(x,100)
plt.scatter(x,y)

# %%
x = pd.DataFrame(x,columns=['X_Values'])
y = pd.DataFrame(y,columns=['Y_values'])
data = x.join(y)

# %%
def lossFunction(m,b,points):
  tot_error = 0
  for i in range(len(points)):
    tot_error += (y[i] - ((m*x)+b))**2
  tot_error = float((tot_error)/len(101))

# %%
def gradient_descent(m_now,b_now,L,points):
  m_g = 0
  b_g = 0


  for i in range(len(points)):
    x = points.iloc[i].X_Values
    y = points.iloc[i].Y_values
    m_g += -(2/100)* (x *(y- (m_now*x+b_now)))
    b_g += -(2/100)*(y -( m_now*x+b_now))

  m = m_now - m_g*L
  b = b_now - b_g*L

  return m,b

# %%
epoch = 300
m = 0
b = 0
L = 0.00000009

for i in range(epoch):
  m , b = gradient_descent(m,b,L,data)

print(m,b)
# Out:
# 0.055919776196748504 0.007188087135880372

# %%
plt.scatter(data.Y_values,data.X_Values,color="black")
plt.plot(list(range(50,200)),[m * x + b for x in range(50,200)],color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-d89fc0d18f9f> in <cell line: 3>()
#       1 plt.scatter(data.Y_values,data.X_Values,color="black")
#       2 plt.plot(list(range(50,200)),[m * x + b for x in range(50,200)],color='red')
# ----> 3 plt.scatter(y,10)
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...
